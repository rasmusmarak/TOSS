# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import sys
sys.path.append('..')

import visualization.plotting_utility as plotting_utility

# %%
# plot strong scaling (small run)
generations = [10, 10, 10, 10, 10, 10]
islands = [1, 2, 4, 8, 16, 32]
populations = [640, 320, 160, 80, 40, 20]

strong_scale_small_run = np.genfromtxt('strong_scaling_small_run.csv', delimiter=',')

core_counts = islands
run_times = strong_scale_small_run[-1,:]

plotting_utility.plot_performance_scaling(core_counts, run_times)

# %%
# plot strong scaling (large run)
generations = [40, 40, 40, 40, 40, 40]
islands = [1, 2, 4, 8, 16, 32]
populations = [640, 320, 160, 80, 40, 20]

strong_scale_large_run = np.genfromtxt('strong_scaling_large_run.csv', delimiter=',')

core_counts = islands
run_times = strong_scale_large_run[-1,:]

plotting_utility.plot_performance_scaling(core_counts, run_times)

# %%
# plot weak scaling
generations = [32, 32, 32, 32, 32, 32]
islands =  [1, 2, 4, 8, 16, 32]
populations = [20, 20, 20, 20, 20, 20]

weak_scale = np.genfromtxt('weak_scaling.csv', delimiter=',')

core_counts = islands
run_times = weak_scale[-1,:]

plotting_utility.plot_performance_scaling(core_counts, run_times)

# %%
import numpy as np
import matplotlib.pyplot as plt
generations = np.arange(1,1001,1)
fitness_over_gen = np.genfromtxt('fitness_over_generations_long_run.csv', delimiter=',')
plt.plot(generations, fitness_over_gen)
plt.xlabel("Generations")
plt.ylabel("Fitness value")
# Out:
# Text(0, 0.5, 'Fitness value')
